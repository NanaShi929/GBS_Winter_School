# %% [markdown]
# <a href="https://colab.research.google.com/github/NanaShi929/GBS_Winter_School/blob/main/GBS_Winter_School.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: print hello world

print("hello world")
# Out:
# hello world

# %%
1+2+3+4+5+6+7+8+9
# Out:
# 45

# %%
1-2-3-4-5-6-7-8-9
# Out:
# -43

# %%
1*2*3*4*5*6*7*8*9
# Out:
# 362880

# %%
1/2/3/4/5/6/7/8/9
# Out:
# 2.7557319223985893e-06

# %% [markdown]
# Hello World
#
#
# ---
#
#
#
# ---

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$
#
#
#
# ---
#
#
#
# ---
#
# $e^x=\sum_{i=0}^\infty \frac{1}{i}x^2$

# %%
# prompt: code to upload excel file

from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# now you can access uploaded files using their names
# for example:
# import pandas as pd
# df = pd.read_excel('your_excel_file.xlsx') # replace 'your_excel_file.xlsx' with the actual filename
# print(df)
# Out:
#      <input type="file" id="files-5bb3476b-f3b4-43a6-8f10-426da1c79eb3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bb3476b-f3b4-43a6-8f10-426da1c79eb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install matplotlib

# %%
# prompt: code to upload excel file

import pandas as pd
import io

for fn in uploaded.keys():
  if fn.endswith('.xlsx') or fn.endswith('.xls'):  # Check if the uploaded file is an Excel file
    df = pd.read_excel(io.BytesIO(uploaded[fn]))
    print(df)
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#           Date            Y            X
# 0   2021-10-06  35075.80078  14501.91016
# 1   2021-10-07  35703.85156  14654.01953
# 2   2021-10-08  36402.00000  14579.54004
# 3   2021-10-11  35179.94922  14486.20020
# 4   2021-10-12  34869.75000  14465.91992
# ..         ...          ...          ...
# 228 2022-09-22  26782.65039  11066.80957
# 229 2022-09-23  26592.34961  10867.92969
# 230 2022-09-26  26743.65039  10802.91992
# 231 2022-09-27  27004.15039  10829.50000
# 232 2022-09-28  27067.65039  11051.63965
#
# [233 rows x 3 columns]

# %%
# prompt: Codes to create single chart with all variables

import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame created from the uploaded Excel file.
# Replace this with your actual DataFrame if it's named differently.

try:
  df.plot(kind='line') # You can change 'line' to other chart types like 'bar', 'scatter', etc.
  plt.title('Combined Chart of all variables')
  plt.xlabel('Index') # Replace with a suitable label if needed
  plt.ylabel('Values') # Replace with a suitable label if needed
  plt.legend()
  plt.show()
except NameError:
  print("The variable 'df' is not defined. Please ensure an Excel file is uploaded and processed correctly.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# prompt: Codes to create individual chart of all variables

from google.colab import files
import pandas as pd
import io
import matplotlib.pyplot as plt

# ... (Your existing code)

try:
  for col in df.columns:
    plt.figure()  # Create a new figure for each variable
    df[col].plot(kind='line')  # Plot individual variable
    plt.title(f'Chart of {col}')
    plt.xlabel('Index')
    plt.ylabel(col)
    plt.legend()
    plt.show()
except NameError:
  print("The variable 'df' is not defined. Please ensure an Excel file is uploaded and processed correctly.")
except KeyError as e:
    print(f"Column '{e}' not found in the DataFrame.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# prompt: codes to create 5 different types of charts of all variable from uploaded excel file

import pandas as pd
import matplotlib.pyplot as plt
import io
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.head()) # print first few rows for verification

      # Define chart types and corresponding plotting functions
      chart_types = {
          'line': df.plot.line,
          'bar': df.plot.bar,
          'scatter': df.plot.scatter,
          'hist': df.plot.hist,
          'box': df.plot.box
      }


      for col in df.columns:
        for chart_name, chart_func in chart_types.items():
            plt.figure(figsize=(8, 6))  # Adjust figure size if needed
            try:
              if chart_name in ['scatter', 'line']:
                  if len(df.columns) > 1:
                      chart_func(x=df.columns[0], y=col)
                  else:
                      chart_func(y=col)
              else:
                chart_func(y=col)

              plt.title(f'{chart_name.capitalize()} chart of {col}')
              plt.xlabel('Index' if chart_name != 'hist' else col)
              plt.ylabel(col)
              plt.show()
            except ValueError as e:
              print(f"Error plotting {chart_name} for {col}: {e}")


    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break # process only the first excel file
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-8b20f0b1-4d86-4e73-bba4-2da2a238c0bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b20f0b1-4d86-4e73-bba4-2da2a238c0bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: Codes to create individual chart of all variables

# ... (Your existing code)

try:
    for col in df.columns:
        plt.figure()  # Create a new figure for each variable
        df[col].plot(kind='line')  # Plot individual variable
        plt.title(f'Chart of {col}')
        plt.xlabel('Index')
        plt.ylabel(col)
        plt.legend()
        plt.show()
except NameError:
    print("The variable 'df' is not defined. Please ensure an Excel file is uploaded and processed correctly.")
except KeyError as e:
    print(f"Column '{e}' not found in the DataFrame.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# prompt: Codes to create individual chart of all variables with different types of charts for every single variable of all variavble

import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import io

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.head())

      chart_types = {
          'line': df.plot.line,
          'bar': df.plot.bar,
          'hist': df.plot.hist,
          'box': df.plot.box
      }

      for col in df.columns:
        for chart_name, chart_func in chart_types.items():
          plt.figure(figsize=(8, 6))
          try:
            if chart_name == 'hist':
              chart_func(y=col)
            elif chart_name == 'box':
              chart_func(y=col)
            elif len(df.columns) > 1:
              chart_func(x=df.columns[0], y=col) # Assuming first column is x-axis
            else:
              chart_func(y=col)

            plt.title(f'{chart_name.capitalize()} chart of {col}')
            plt.xlabel('Index' if chart_name != 'hist' else col)
            plt.ylabel(col)
            plt.show()
          except ValueError as e:
            print(f"Error plotting {chart_name} for {col}: {e}")
    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-a02d92d6-1ff3-496b-90ae-8ca2eac78f91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a02d92d6-1ff3-496b-90ae-8ca2eac78f91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: Codes to create individual chart of all variables with different types of charts for every single variable

import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import io

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.head())

      chart_types = {
          'line': df.plot.line,
          'bar': df.plot.bar,
          'hist': df.plot.hist,
          'box': df.plot.box,
          'kde': df.plot.kde
      }

      for col in df.columns:
        for chart_name, chart_func in chart_types.items():
          plt.figure(figsize=(8, 6))
          try:
            if chart_name in ('hist', 'kde', 'box'):
              chart_func(y=col)
            elif len(df.columns) > 1 :
              chart_func(x=df.columns[0], y=col)
            else:
              chart_func(y=col)

            plt.title(f'{chart_name.capitalize()} chart of {col}')
            plt.xlabel('Index' if chart_name not in ('hist', 'kde') else col)
            plt.ylabel(col)
            plt.show()
          except ValueError as e:
            print(f"Error plotting {chart_name} for {col}: {e}")
    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break  # Process only the first Excel file
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-3379b248-7b83-4c1b-9b81-f0cdd64866ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3379b248-7b83-4c1b-9b81-f0cdd64866ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = '/mnt/data/Data 2 (3).xlsx'
data = pd.read_excel(file_path)

# Ensure the "Month" column is in datetime format
data['Month'] = pd.to_datetime(data['Month'])

# 1. Line Chart - GDP over Time
plt.figure(figsize=(10, 6))
plt.plot(data['Month'], data['GDP'], marker='o', label='GDP')
plt.title('GDP Over Time')
plt.xlabel('Month')
plt.ylabel('GDP')
plt.legend()
plt.grid()
plt.show()

# 2. Bar Chart - Average values of GDP, PCE, Inv, and G
average_values = data[['GDP', 'PCE', 'Inv', 'G']].mean()
plt.figure(figsize=(10, 6))
average_values.plot(kind='bar', color=['blue', 'orange', 'green', 'red'])
plt.title('Average Values of GDP, PCE, Inv, and G')
plt.ylabel('Value')
plt.show()

# 3. Scatter Plot - PCE vs GDP
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['PCE'], y=data['GDP'], hue=data['Month'].dt.year, palette='viridis')
plt.title('PCE vs GDP')
plt.xlabel('PCE')
plt.ylabel('GDP')
plt.colorbar(label='Year')
plt.show()

# 4. Box Plot - Distribution of GDP by Year
data['Year'] = data['Month'].dt.year
plt.figure(figsize=(10, 6))
sns.boxplot(x='Year', y='GDP', data=data, palette='Set2')
plt.title('GDP Distribution by Year')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# 5. Area Chart - GDP, PCE, Inv, and G Over Time
plt.figure(figsize=(10, 6))
plt.stackplot(data['Month'], data['GDP'], data['PCE'], data['Inv'], data['G'], labels=['GDP', 'PCE', 'Inv', 'G'], alpha=0.8)
plt.title('Components Over Time')
plt.xlabel('Month')
plt.ylabel('Value')
plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-de120bb1a3b4> in <cell line: 7>()
#       5 # Load the Excel file
#       6 file_path = '/mnt/data/Data 2 (3).xlsx'
# ----> 7 data = pd.read_excel(file_path)
#       8
#       9 # Ensure the "Month" column is in datetime format
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
# prompt: code to upload a excel file

from google.colab import files
import io
import pandas as pd
import matplotlib.pyplot as plt

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.head())

      # ... (rest of your existing code for plotting) ...
    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break  # Process only the first Excel file
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-f9444086-da60-42ac-bf51-ea0088fe3069" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9444086-da60-42ac-bf51-ea0088fe3069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Upload the file to the Colab environment
uploaded = files.upload()

# Get the filename from the uploaded files
filename = list(uploaded.keys())[0]

# Read the uploaded file into a pandas DataFrame
data = pd.read_excel(filename)

# Ensure the "Month" column is in datetime format
data['Month'] = pd.to_datetime(data['Month'])

plt.figure(figsize=(10, 6))
plt.plot(data['Month'], data['GDP'], marker='o', label='GDP', color='blue')
plt.title('GDP Over Time')
plt.xlabel('Month')
plt.ylabel('GDP')
plt.legend()
plt.grid()
plt.show()

# 2. Bar Chart - Average values of GDP, PCE, Inv, and G
average_values = data[['GDP', 'PCE', 'Inv', 'G']].mean()
plt.figure(figsize=(10, 6))
average_values.plot(kind='bar', color=['blue', 'orange', 'green', 'red'])
plt.title('Average Values of GDP, PCE, Inv, and G')
plt.ylabel('Value')
plt.show()

# 3. Scatter Plot - PCE vs GDP
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(x=data['PCE'], y=data['GDP'], hue=data['Month'].dt.year, palette='viridis')
scatter.legend(title='Year')
plt.title('PCE vs GDP')
plt.xlabel('PCE')
plt.ylabel('GDP')
plt.show()

# 4. Box Plot - Distribution of GDP by Year
data['Year'] = data['Month'].dt.year
plt.figure(figsize=(10, 6))
sns.boxplot(x='Year', y='GDP', data=data, palette='Set2')
plt.title('GDP Distribution by Year')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# 5. Area Chart - GDP, PCE, Inv, and G Over Time
plt.figure(figsize=(10, 6))
plt.stackplot(data['Month'], data['GDP'], data['PCE'], data['Inv'], data['G'], labels=['GDP', 'PCE', 'Inv', 'G'], alpha=0.8)
plt.title('Components Over Time')
plt.xlabel('Month')
plt.ylabel('Value')
plt.legend(loc='upper left')
plt.show()
# Out:
#      <input type="file" id="files-022f5788-a43b-426f-bf0f-da481038746c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-022f5788-a43b-426f-bf0f-da481038746c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to genate 5 different types of charts using uploaded file

from google.colab import files
import pandas as pd
import io
import matplotlib.pyplot as plt
import seaborn as sns

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.head())

      # 1. Line Chart
      plt.figure(figsize=(8, 6))
      if len(df.columns) > 1:
        df.plot(x=df.columns[0], y=df.columns[1], kind='line', ax=plt.gca()) # Assuming first column is x-axis, second column is y
      else:
        df.plot(y=df.columns[0], kind='line', ax=plt.gca())
      plt.title('Line Chart')
      plt.show()

      # 2. Bar Chart
      plt.figure(figsize=(8, 6))
      df[df.columns[0]].value_counts().plot(kind='bar')  # Assuming the first column is categorical
      plt.title('Bar Chart')
      plt.show()

      # 3. Histogram
      plt.figure(figsize=(8, 6))
      df.hist(column=df.columns[1])
      plt.title('Histogram')
      plt.show()


      # 4. Scatter Plot
      plt.figure(figsize=(8, 6))
      if len(df.columns) > 1:
          plt.scatter(df[df.columns[0]], df[df.columns[1]])
          plt.xlabel(df.columns[0])
          plt.ylabel(df.columns[1])
      plt.title('Scatter Plot')
      plt.show()

      # 5. Box Plot
      plt.figure(figsize=(8, 6))
      if len(df.columns) > 0:
        df.boxplot(column=df.columns[1])  # Create box plot for second column
        plt.title('Box Plot')
        plt.show()

    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break  # Process only the first Excel file
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-d093e779-4341-4ab5-91ed-b115b403d8af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d093e779-4341-4ab5-91ed-b115b403d8af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to combine all the charts

import pandas as pd
import matplotlib.pyplot as plt
import io
from google.colab import files
import seaborn as sns

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.head())

      #Combined line chart of all numeric columns
      numeric_cols = df.select_dtypes(include=['number'])
      plt.figure(figsize=(10, 6))
      for col in numeric_cols.columns:
          plt.plot(df.index, numeric_cols[col], label=col)
      plt.title("Combined Line Chart of Numeric Columns")
      plt.xlabel("Index")
      plt.ylabel("Values")
      plt.legend()
      plt.show()

      #Individual Charts
      for col in df.columns:
        plt.figure(figsize=(8, 6))
        if pd.api.types.is_numeric_dtype(df[col]):
          # For numeric data, create different chart types
            plt.subplot(2, 2, 1)
            df[col].plot(kind='line')
            plt.title(f'Line Chart of {col}')

            plt.subplot(2, 2, 2)
            df[col].plot(kind='hist')
            plt.title(f'Histogram of {col}')

            plt.subplot(2, 2, 3)
            df.boxplot(column=col)
            plt.title(f'Box Plot of {col}')

            plt.subplot(2, 2, 4)
            df[col].plot(kind='kde')
            plt.title(f'KDE Plot of {col}')
            plt.tight_layout() #adjust subplot params for a tight layout.
            plt.show()
        else:
          # For non-numeric data, create a bar chart of value counts
            df[col].value_counts().plot(kind='bar')
            plt.title(f'Bar Chart of {col}')
            plt.show()

    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break  # Process only the first Excel file
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-6104f53a-094e-4b3d-b03f-28990db2d2d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6104f53a-094e-4b3d-b03f-28990db2d2d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to download bar graph in 300dpi

import matplotlib.pyplot as plt

# ... (Your existing code)

# ... (Your plotting code) ...

# Save the plot with 300 dpi
plt.savefig('my_plot_300dpi.png', dpi=300)

#Optional: Download the saved image
from google.colab import files
files.download('my_plot_300dpi.png')

# %%
# prompt: codes to upload multiple excel file

from google.colab import files
import pandas as pd
import io
import matplotlib.pyplot as plt

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(f"Successfully uploaded and read: {fn}")

      # ... (Your existing code for plotting) ...
      # Example plots (customize as needed)

      #Combined line chart of all numeric columns
      numeric_cols = df.select_dtypes(include=['number'])
      plt.figure(figsize=(10, 6))
      for col in numeric_cols.columns:
          plt.plot(df.index, numeric_cols[col], label=col)
      plt.title("Combined Line Chart of Numeric Columns")
      plt.xlabel("Index")
      plt.ylabel("Values")
      plt.legend()
      plt.show()

      # Individual charts for each column
      for col in df.columns:
        plt.figure(figsize=(8, 6))
        if pd.api.types.is_numeric_dtype(df[col]):
          #Numeric columns
            df[col].plot(kind='line')
            plt.title(f'Line Chart of {col}')
            plt.show()

            df[col].plot(kind='hist')
            plt.title(f'Histogram of {col}')
            plt.show()

            df.boxplot(column=col)
            plt.title(f'Box Plot of {col}')
            plt.show()

        else:
          # Categorical columns
          df[col].value_counts().plot(kind='bar')
          plt.title(f'Bar Chart of {col}')
          plt.show()

    except Exception as e:
      print(f"Error reading or processing '{fn}': {e}")
  else:
    print(f"Skipping non-Excel file: {fn}")
# Out:
#      <input type="file" id="files-31a62f30-8497-4f2b-9802-1e03f5ee03ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31a62f30-8497-4f2b-9802-1e03f5ee03ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files # Import files for uploading

# Upload the file to Colab
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Get the name of the uploaded file

# Load the Excel file
data = pd.read_excel(file_path)

# Ensure the "Month" column is in datetime format (if it exists)
if 'Month' in data.columns:
    data['Month'] = pd.to_datetime(data['Month'])

# Prepare the data for the bar chart (example: plotting GDP over time)
plt.figure(figsize=(10, 6))
plt.bar(data['Month'] if 'Month' in data.columns else data.index, data['GDP'] if 'GDP' in data.columns else data.iloc[:, 0], color='blue') # Using index if 'Month' not found, and first column if 'GDP' not found
plt.title('GDP Over Time')
plt.xlabel('Month' if 'Month' in data.columns else 'Index') # Using 'Index' as x-axis label if 'Month' not found
plt.ylabel('GDP' if 'GDP' in data.columns else data.columns[0]) # Using first column name as y-axis label if 'GDP' not found
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping

# Save the bar chart as a JPEG file with 300 DPI
output_path = 'GDP_Bar_Chart.jpg' # Saving to current directory
plt.savefig(output_path, format='jpg', dpi=300)
plt.show()

print(f"Bar chart saved as: {output_path}")
files.download(output_path)
# Out:
#      <input type="file" id="files-9fa3a2f6-a6b0-4b98-9aca-259e8f8342df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9fa3a2f6-a6b0-4b98-9aca-259e8f8342df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to summary statistics

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import io

uploaded = files.upload()

for fn in uploaded.keys():
  if fn.endswith(('.xls', '.xlsx')):
    try:
      df = pd.read_excel(io.BytesIO(uploaded[fn]))
      print(df.describe()) # Summary statistics

      # ... (rest of your existing code for plotting) ...
    except Exception as e:
      print(f"Error reading or processing the Excel file: {e}")
    break  # Process only the first Excel file
  else:
    print(f"Uploaded file '{fn}' is not an Excel file.")
# Out:
#      <input type="file" id="files-b3dfecda-c063-4abb-b663-d1edc478c979" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3dfecda-c063-4abb-b663-d1edc478c979">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to discriptive statistics

# Assuming 'df' is your DataFrame (loaded from the Excel file)

# Descriptive statistics for all numerical columns
print(df.describe())


# Descriptive statistics for a specific column (e.g., 'GDP')
if 'GDP' in df.columns:
    print("\nDescriptive statistics for GDP:")
    print(df['GDP'].describe())
else:
    print("\n'GDP' column not found in the DataFrame.")
# Out:
#                 M1       Tbill         CPI          IP
# count   624.000000  624.000000  624.000000  624.000000
# mean    724.715224    5.127516  110.943042   60.048082
# std     503.284943    2.957858   63.780290   23.108212
# min     139.600000    0.010000   29.370000   22.073700
# 25%     250.925000    3.265000   42.650000   41.194975
# 50%     620.600000    4.960000  109.000000   54.865950
# 75%    1122.450000    6.452500  164.475000   85.216525
# max    2167.800000   16.300000  227.033000  100.742000
#
# 'GDP' column not found in the DataFrame.
