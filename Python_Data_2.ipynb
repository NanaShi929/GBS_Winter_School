# %% [markdown]
# <a href="https://colab.research.google.com/github/NanaShi929/GBS_Winter_School/blob/day-2/Python_Data_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: code to upload exel file

from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# now you can use the uploaded file using its name
# for example if the name of the file is my_excel_file.xlsx
# you can use pandas to read it
# import pandas as pd
# df = pd.read_excel('my_excel_file.xlsx')
# print(df.head())
# Out:
#      <input type="file" id="files-9b38c7b5-7deb-408c-9a0c-5b8ea47753fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b38c7b5-7deb-408c-9a0c-5b8ea47753fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to install matplotlib

# !pip install matplotlib

# %%
# prompt: code to install seaborn

# !pip install seaborn

# %%
# prompt: code to create individual line graph for GDP, PCE ,Inv ,G vs months(x axis) from excel file

import pandas as pd
import matplotlib.pyplot as plt

# Assuming your excel file is named 'my_excel_file.xlsx'
# Replace 'my_excel_file.xlsx' with the actual filename if different
try:
  df = pd.read_excel('Data 2.xlsx')
except FileNotFoundError:
  print("Error: 'my_excel_file.xlsx' not found. Please upload the correct file.")
  exit()


# Assuming your excel file has columns named 'Month', 'GDP', 'PCE', 'Inv', and 'G'
# Replace with the actual column names if different

#Check if required columns exist in the DataFrame
required_cols = ['Month', 'GDP', 'PCE', 'Inv', 'G']
if not all(col in df.columns for col in required_cols):
    print("Error: The DataFrame does not contain all the required columns ('Month', 'GDP', 'PCE', 'Inv', 'G'). Please check your excel file.")
    exit()

# Create individual line graphs
plt.figure(figsize=(12, 6))

plt.plot(df['Month'], df['GDP'], label='GDP')
plt.xlabel('Month')
plt.ylabel('GDP Value')
plt.title('GDP vs. Month')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['PCE'], label='PCE', color='red')
plt.xlabel('Month')
plt.ylabel('PCE Value')
plt.title('PCE vs. Month')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['Inv'], label='Inv', color='green')
plt.xlabel('Month')
plt.ylabel('Inv Value')
plt.title('Inv vs. Month')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['G'], label='G', color='purple')
plt.xlabel('Month')
plt.ylabel('G Value')
plt.title('G vs. Month')
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: code to do above graph in line chart

from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# !pip install matplotlib

try:
  df = pd.read_excel('Data 2.xlsx')
except FileNotFoundError:
  print("Error: 'Data 2.xlsx' not found. Please upload the correct file.")
  exit()

required_cols = ['Month', 'GDP', 'PCE', 'Inv', 'G']
if not all(col in df.columns for col in required_cols):
    print("Error: The DataFrame does not contain all the required columns ('Month', 'GDP', 'PCE', 'Inv', 'G'). Please check your excel file.")
    exit()

# Create a single line graph with multiple lines
plt.figure(figsize=(12, 6))

plt.plot(df['Month'], df['GDP'], label='GDP', marker='o')
plt.plot(df['Month'], df['PCE'], label='PCE', marker='o', color='red')
plt.plot(df['Month'], df['Inv'], label='Inv', marker='o', color='green')
plt.plot(df['Month'], df['G'], label='G', marker='o', color='purple')

plt.xlabel('Month')
plt.ylabel('Value')
plt.title('GDP, PCE, Inv, and G vs. Month')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#      <input type="file" id="files-d4ab6930-9b98-4a03-885b-013373d2531f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4ab6930-9b98-4a03-885b-013373d2531f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: code to create Line chart

import pandas as pd
import matplotlib.pyplot as plt

# Assuming your excel file is named 'Data 2.xlsx' and is already uploaded
# Replace 'Data 2.xlsx' with the actual filename if different
try:
    df = pd.read_excel('Data 2.xlsx')
except FileNotFoundError:
    print("Error: 'Data 2.xlsx' not found. Please upload the correct file.")
    exit()

#Check if required columns exist in the DataFrame
required_cols = ['Month', 'GDP', 'PCE', 'Inv', 'G']
if not all(col in df.columns for col in required_cols):
    print("Error: The DataFrame does not contain all the required columns ('Month', 'GDP', 'PCE', 'Inv', 'G'). Please check your excel file.")
    exit()

# Create a single line graph with multiple lines
plt.figure(figsize=(12, 6))

plt.plot(df['Month'], df['GDP'], label='GDP')
plt.plot(df['Month'], df['PCE'], label='PCE', color='red')
plt.plot(df['Month'], df['Inv'], label='Inv', color='green')
plt.plot(df['Month'], df['G'], label='G', color='purple')

plt.xlabel('Month')
plt.ylabel('Value')
plt.title('GDP, PCE, Inv, and G vs. Month')
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: code to download all the above graph in jpg format in 300dpi

import matplotlib.pyplot as plt

# ... (Your existing code) ...

# Save the individual line graphs as JPG files with 300 DPI
plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['GDP'], label='GDP')
plt.xlabel('Month')
plt.ylabel('GDP Value')
plt.title('GDP vs. Month')
plt.legend()
plt.grid(True)
plt.savefig('gdp_plot.jpg', dpi=300) #saving GDP plot
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['PCE'], label='PCE', color='red')
plt.xlabel('Month')
plt.ylabel('PCE Value')
plt.title('PCE vs. Month')
plt.legend()
plt.grid(True)
plt.savefig('pce_plot.jpg', dpi=300) #saving PCE plot
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['Inv'], label='Inv', color='green')
plt.xlabel('Month')
plt.ylabel('Inv Value')
plt.title('Inv vs. Month')
plt.legend()
plt.grid(True)
plt.savefig('inv_plot.jpg', dpi=300) #saving Inv plot
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['G'], label='G', color='purple')
plt.xlabel('Month')
plt.ylabel('G Value')
plt.title('G vs. Month')
plt.legend()
plt.grid(True)
plt.savefig('g_plot.jpg', dpi=300) #saving G plot
plt.show()


# ... (rest of your existing code) ...

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['GDP'], label='GDP')
plt.plot(df['Month'], df['PCE'], label='PCE', color='red')
plt.plot(df['Month'], df['Inv'], label='Inv', color='green')
plt.plot(df['Month'], df['G'], label='G', color='purple')
plt.xlabel('Month')
plt.ylabel('Value')
plt.title('GDP, PCE, Inv, and G vs. Month')
plt.legend()
plt.grid(True)
plt.savefig('combined_plot.jpg', dpi=300) #saving combined plot
plt.show()

from google.colab import files
files.download('gdp_plot.jpg')
files.download('pce_plot.jpg')
files.download('inv_plot.jpg')
files.download('g_plot.jpg')
files.download('combined_plot.jpg')

# %%
# prompt: code to create summary statsticks which include mean , medium, mode, JB stat, JB P-value,skiwness,kurtosis,obeservation  and download it in excel format

import pandas as pd
from scipy.stats import skew, kurtosis, jarque_bera
from statistics import mean, median, mode

try:
    df = pd.read_excel('Data 2.xlsx')
except FileNotFoundError:
    print("Error: 'Data 2.xlsx' not found. Please upload the correct file.")
    exit()

required_cols = ['GDP', 'PCE', 'Inv', 'G']
if not all(col in df.columns for col in required_cols):
    print("Error: The DataFrame does not contain all the required columns ('GDP', 'PCE', 'Inv', 'G'). Please check your excel file.")
    exit()

summary_stats = {}

for col in required_cols:
    data = df[col]
    summary_stats[col] = {
        'Mean': mean(data),
        'Median': median(data),
        'Mode': mode(data) if len(data.mode()) > 0 else "No unique mode",  # Handle cases with no unique mode
        'Observations': len(data),
        'Skewness': skew(data),
        'Kurtosis': kurtosis(data),
        'JB_Statistic': jarque_bera(data)[0],
        'JB_P_value': jarque_bera(data)[1]
    }

summary_df = pd.DataFrame(summary_stats).transpose()
summary_df.index.name = "Variable"


# Downloading the summary statistics to an excel file
summary_df.to_excel('summary_statistics.xlsx')
from google.colab import files
files.download('summary_statistics.xlsx')

# %%
# prompt: code to create correlation

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and it's already loaded
# Replace 'Data 2.xlsx' with the actual filename if different


try:
    df = pd.read_excel('Data 2.xlsx')
except FileNotFoundError:
    print("Error: 'Data 2.xlsx' not found. Please upload the correct file.")
    exit()

required_cols = ['GDP', 'PCE', 'Inv', 'G']
if not all(col in df.columns for col in required_cols):
    print("Error: The DataFrame does not contain all the required columns ('GDP', 'PCE', 'Inv', 'G'). Please check your excel file.")
    exit()

# Calculate the correlation matrix
correlation_matrix = df[required_cols].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.savefig('Correlation_Matrix.jpg', dpi=300)
plt.show()
files.download('Correlation_Matrix.jpg')

# %%
# prompt: code to create excel file for correlation and p-value

import pandas as pd
from scipy.stats import pearsonr

try:
    df = pd.read_excel('Data 2.xlsx')
except FileNotFoundError:
    print("Error: 'Data 2.xlsx' not found. Please upload the correct file.")
    exit()

required_cols = ['GDP', 'PCE', 'Inv', 'G']
if not all(col in df.columns for col in required_cols):
    print("Error: The DataFrame does not contain all the required columns ('GDP', 'PCE', 'Inv', 'G'). Please check your excel file.")
    exit()

# Create an empty dictionary to store correlation and p-value
correlation_results = {}

# Calculate correlation and p-value for each pair of columns
for i in range(len(required_cols)):
    for j in range(i + 1, len(required_cols)):
        col1 = required_cols[i]
        col2 = required_cols[j]
        correlation, p_value = pearsonr(df[col1], df[col2])
        correlation_results[(col1, col2)] = {'Correlation': correlation, 'P-value': p_value}

# Convert the dictionary to a DataFrame
correlation_df = pd.DataFrame.from_dict(correlation_results, orient='index')

# Save the correlation and p-value data to an Excel file
correlation_df.to_excel('correlation_pvalue.xlsx')

from google.colab import files
files.download('correlation_pvalue.xlsx')
